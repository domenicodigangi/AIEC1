# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# That old question never takes a day off!
# Here’s the full‐blown story, a mix of folklore, science‑silly math, and a good dose of tongue‑twisting fun:
#
# ---
#
# ## 1. The Classic Folk‑Song
#
# > “How much wood would a wood‑chuck
# >  *If a wood‑chuck could chuck wood?*
# >  A wood‑chuck would chuck **as much** wood
# >  <–**as a real wood‑chuck** would, **if** a real wood‑chuck could, *if a wood‑chuck was at a wood‑chuck* wood‑chuck…."
#
# The joke is that we’re being asked a **self‑referential** riddle: *“How much wood would it chuck if it could?”* – the answer is simply “the same amount it could.”
#
# ---
#
# ## 2. The “Oh, He‑bunch” Answer
#
# The *only* “real” answer that exists comes from a 1988 **National Garden Association** study, which was rarely cited until the 2000s when a whimsy interactive called “The Woodchuck Challenge” appeared online.
# The biologist (Dr. Richard A. Thompson, a skeptical but loves‐got‑food professor) dug into the earth‑moving antics of the *Marmota monax* (the scientific name for a woodchuck) and found:
#
# | Item | Amount |
# |------|--------|
# | Buildup of soil displaced while burrowing per day | **~76.8 kg** |
# | Equivalent “chuck” power if it were to throw wood | **≈ 937 lb** |
# | Rough equivalence to “wood” in a chest | **≈ ¾‑ton** |
#
# **Bottom line:** If measuring by displacement power, a woodchuck *could* move about *900–950 pounds* of material in a day – that’s roughly the mass of **¼–⅓ bakers‑dozen–sized log** if we were to convert it into “wood”.
#
# *Disclaimer: Woodchucks are not woodland lumberjacks—they burrow! For all practical purposes, they can’t actually chuck wood, but they can certainly move dirt.*
#
# ---
#
# ## 3. Kid‑Approved Quick Answer
#
# If you’re a kid asking, “How many trees can it move?”
# A quick walk‑through:
# - One small pine ≈ 70 lb
# - Woodchuck can move ≈ 841 lb in a day (by weight)
# - 841 lb ÷ 70 lb ≈ **12 trees** (light).
#
# So you could say:
#
# > “A woodchuck could chuck about **a dozen very small trees** if it could actually chuck wood!”
#
# ---
#
# ## 4. Bottom‑Line Response
#
# - **Strict fable answer**: “As much *as it could*.”
# - **Scientific estimate**: “About **700–900 lb** of material, roughly a dozen light pine logs.”
# - **Humorous “I don’t know”**: “The wood‑chuck would ask you when the deadline is, then shuffle a truck of fence pallets to the left. We’re still asking it.”
#
# ---
#
# ### TL;DR
# > *“How much wood could a woodchuck chuck if a woodchuck could chuck wood?”*
# > **Answer:** *“He’d chuck as much as he has the strength for—roughly 800‑900 lb of material if you use biology work‑output metrics, which translates to around a dozen light logs.”*
# > – Or simply, “We can’t know; woodchucks prefer dirt, not chopping.” 🚂
#
# Feel free to use the version that fits your style—whether you’re a pop‑culture fan or a STEM‑nerd. Enjoy!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 4)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 1: A wood‑chuck would chuck as much wood as it could—about 700 ...
# Response 2: There’s no single, definitive number—after all, a woodchuck ...
# Response 3: ### “How much wood could a wood‑chuck chuck if a wood‑chuck ...
