# %% [markdown]
# # Your First Vector RAG Application: Cat Health Assistant
#
# In this notebook, we will build a dense vector retrieval application using **LangChain v1**, **OpenAI embeddings**, and **Qdrant** as an in-memory vector database.
#
# The goal is to understand the core RAG loop:
#
# 1. Load a cat health guideline PDF
# 2. Split it into smaller chunks
# 3. Embed those chunks
# 4. Store the embeddings in Qdrant
# 5. Retrieve relevant chunks for a question
# 6. Generate an answer grounded in the retrieved context
#
# > Note: This notebook expects Python 3.12 and uses uv for dependency management.
#
# > Note: This is a vector RAG lesson, not a veterinary care tool. The assistant should answer from the PDF and point users to a veterinarian for diagnosis, treatment, medication, or urgent care decisions.

# %% [markdown]
# ## Table of Contents
#
# - Task 1: Environment Setup
# - Task 2: Embedding Similarity Primer
# - Task 3: Documents - Loading the Cat Health Guideline PDF
# - Task 4: Chunking the Documents
# - Task 5: Embeddings and Qdrant
# - Task 6: Retrieval with Scores
# - Task 7: Retrieval Augmented Generation
# - Activity: Tune Retrieval Quality

# %% [markdown]
# ## Task 1: Environment Setup
#
# From the `01_Dense_Vector_Retrieval` folder, install dependencies with uv:
#
# ```bash
# uv sync
# ```
#
# Then open this notebook in Cursor or VS Code and select the Python/Jupyter environment created by uv.

# %% [markdown]
# ### Imports
#
# LangChain v1 separates integrations into partner packages. We will use:
#
# - `langchain_community` for PDF loading
# - `langchain_text_splitters` for chunking
# - `langchain_openai` for chat and embedding models
# - `langchain_qdrant` for the Qdrant vector store

# %%
from pathlib import Path
from math import sqrt
from getpass import getpass
import os

from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_qdrant import QdrantVectorStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# /tmp/ipykernel_440793/4147450701.py:6: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %% [markdown]
# ### OpenAI API Key
#
# The chat model and embedding model both use OpenAI. If `OPENAI_API_KEY` is not already set in your environment, this cell will ask for it securely.

# %%
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key: ")

# %% [markdown]
# ## Task 2: Embedding Similarity Primer
#
# Before we load a full PDF, let's make dense vector retrieval less mysterious.
#
# An embedding model turns text into a list of numbers. Texts with related meaning should land closer together in that vector space.
#
# A common way to score closeness is **cosine similarity**:
#
# ```text
# cosine_similarity(a, b) = dot_product(a, b) / (length(a) * length(b))
# ```
#
# The intuition: if two vectors point in a similar direction, their cosine similarity is higher. Vector databases like Qdrant use this same idea, but at a much larger scale.

# %%
embedding_model = "text-embedding-3-small"
embeddings = OpenAIEmbeddings(model=embedding_model)

example_texts = [
    "king",
    "queen",
    "banana",
    "cat",
    "veterinarian",
    "cat health guidelines",
]

example_vectors = dict(zip(example_texts, embeddings.embed_documents(example_texts)))


def cosine_similarity(vector_a: list[float], vector_b: list[float]) -> float:
    dot_product = sum(a * b for a, b in zip(vector_a, vector_b))
    length_a = sqrt(sum(a * a for a in vector_a))
    length_b = sqrt(sum(b * b for b in vector_b))
    return dot_product / (length_a * length_b)


comparison_pairs = [
    ("king", "queen"),
    ("king", "banana"),
    ("cat", "veterinarian"),
    ("cat", "cat health guidelines"),
]

for left, right in comparison_pairs:
    score = cosine_similarity(example_vectors[left], example_vectors[right])
    print(f"{left:>22} <> {right:<22} score={score:.3f}")
# Out:
#                   king <> queen                  score=0.591
#                   king <> banana                 score=0.310
#                    cat <> veterinarian           score=0.356
#                    cat <> cat health guidelines  score=0.496

# %% [markdown]
# A few important notes:
#
# - The score is useful for ranking, not as an absolute truth about meaning.
# - Different embedding models can produce different scores.
# - In RAG, we embed each document chunk once, then embed the user's query and search for the nearest chunk vectors.
#
# That is the retrieval part of RAG.

# %% [markdown]
# ## Task 3: Documents
#
# LangChain represents loaded text as `Document` objects. A `Document` has:
#
# - `page_content`: the text
# - `metadata`: information such as source file and page number
#
# We will load one `Document` per PDF page, then split those pages into smaller chunks.

# %% [markdown]
# ### Course PDF
#
# This notebook uses the bundled cat health guideline PDF at:
#
# ```text
# 01_Dense_Vector_Retrieval/data/cat_health_guidelines.pdf
# ```
#
# The next cell checks that the course material is present before we start loading pages.

# %%
pdf_path = Path("data/cat_health_guidelines.pdf")

if not pdf_path.exists():
    raise FileNotFoundError(
        f"Expected the cat health guideline PDF at: {pdf_path.resolve()}\n"
        "The bundled course PDF is missing from this copy of the materials."
    )

# %% [markdown]
# ### Load the PDF
#
# `PyPDFLoader` extracts text from text-based PDFs. If the PDF is scanned images, this loader may return little or no text, and OCR would be needed.

# %%
loader = PyPDFLoader(str(pdf_path))
pages = loader.load()

for page in pages:
    page.metadata["source"] = pdf_path.name
    page.metadata["document_type"] = "cat_health_guideline"

pages = [page for page in pages if page.page_content.strip()]

if not pages:
    raise ValueError(
        "The PDF loaded, but no extractable text was found. "
        "This usually means the PDF is scanned and needs OCR first."
    )

print(f"Loaded {len(pages)} text-containing PDF pages.")
# Out:
# Loaded 22 text-containing PDF pages.

# %%
print(pages[0].page_content[:750])
print("\nMetadata:", pages[0].metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline'}

# %% [markdown]
# #### ❓Question #1
#
# Why is metadata important for a RAG application?
#
# ##### ✅ Answer:
#
# I can think of multiple reasons:
# - Troubleshooting debugging and versioning. Ingestion is an important part of a product involving a RUP pipeline and as such we need to track how it affects overall product behaviour. In metadata, we can for example track:
#   - what actual version of the code we used for ingestion pipeline, what libraries
#   - what ocr approach was used if any
#   - etc ..
# - We can also have metadata that are relevant for the retrieval step itself but are not present in the corpus. For example in a multi document RAG we might classify documents by authority of the source, geographical info etc... We could then use this to refine the retrieval step if appropriate.
# - Metadata can also be relevant to the generation step. For example, tracking page number in metadata could be useful when citing a document passage as the generated text could need to indicate that

# %% [markdown]
# ## Task 4: Chunking the Documents
#
# A full PDF page can be too large or too mixed-topic for high-quality retrieval. We split pages into overlapping chunks so each chunk has enough local context but is still focused.
#
# Here we will start with chunks of 1,000 characters and 200 characters of overlap. The chunk size controls how much text each vector represents; the overlap keeps nearby context from being lost at chunk boundaries.
#
# `RecursiveCharacterTextSplitter` tries to split on natural boundaries first, such as paragraphs and line breaks, before falling back to smaller separators.

# %%
chunk_size = 1000
chunk_overlap = 200

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    add_start_index=True,
)

splits = text_splitter.split_documents(pages)

print(f"Split {len(pages)} pages into {len(splits)} chunks.")
print(f"Chunk size: {chunk_size} characters")
print(f"Chunk overlap: {chunk_overlap} characters")
# Out:
# Split 22 pages into 135 chunks.
# Chunk size: 1000 characters
# Chunk overlap: 200 characters

# %%
sample_chunk = splits[0]
print(sample_chunk.page_content[:750])
print("\nMetadata:", sample_chunk.metadata)
# Out:
# VETERINARY PRACTICE GUIDELINES
# 2021 AAHA/AAFP Feline Life Stage Guidelines*
# Jessica Quimby, DVM, PhD, DACVIM y, Shannon Gowland, DVM, DABVP y, Hazel C. Carney, DVM, MS, DABVP,
# Theresa DePorter, DVM, MRCVS, DACVB, DECAWBM, Paula Plummer, LVT, VTS (ECC, SAIM), Jodi Westropp,
# DVM, PhD, DACVIM
# ABSTRACT
# The guidelines, authored by a Task Force ofexperts in feline clinical medicine, are an update and extension of the AAFP–AAHA
# Feline Life Stage Guidelines published in 2010. The guidelines are published simultaneously in theJournal of Feline Medicine and
# Surgery(volume 23, issue 3, pages 211–233, DOI: 10.1177/1098612X21993657) and theJournal of the American Animal Hospital
# Association(volume 57, issue 2, pages 51–72, DOI: 10.5326/JAAHA-MS-7189). A
#
# Metadata: {'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 0, 'page_label': '1', 'document_type': 'cat_health_guideline', 'start_index': 0}

# %% [markdown]
# #### ❓Question #2
#
# What tradeoff do we make when choosing chunk size and chunk overlap?
#
# ##### ✅ Answer:
#
# - In general, larger chunks give llm more context but can also result in cluttering the context window with less relevant information. Smaller chunks are more focused but the LLM gets less context around semantically relevant text. Also, having larger chunks implies that we can have less chunks put in context. This might result in a less diverse corpus of information upon which to build the response .
# - Chunk overlap affects the cohesion and redundancy of the context . meaning that if we have a larger chunk overlap of course the sources will be much more coherent and the information will be in some sense more complete but we will have a lot of duplication in the retrieved chunks with a waste of context space. On the other hand smaller overlap can risk breaking concepts enough and having only partial aspects of them available in the context.
#
# Use the [Chunk Visualizer](https://chunkviz.up.railway.app/) to experiment with different chunk sizes and overlaps and see how the text boundaries change.

# %% [markdown]
# ## Task 5: Embeddings and Qdrant
#
# Now we apply the same embedding idea to every chunk from the PDF. Qdrant stores those vectors and lets us search for chunks that are close to a query in embedding space.
#
# We already created an OpenAI embedding model in the primer above. The Qdrant collection name is just a label for the set of vectors we are creating.
#
# For this notebook, Qdrant runs in memory with `location=":memory:"`. That means no Docker, no Qdrant Cloud account, and no persistence after the notebook kernel stops.

# %%
collection_name = "cat_health_guidelines"

vector_store = QdrantVectorStore.from_documents(
    documents=splits,
    embedding=embeddings,
    location=":memory:",
    collection_name=collection_name,
    force_recreate=True,
)

print(f"Embedded chunks with: {embedding_model}")
print(f"Built in-memory Qdrant collection: {collection_name}")
# Out:
# Embedded chunks with: text-embedding-3-small
# Built in-memory Qdrant collection: cat_health_guidelines

# %% [markdown]
# ## Task 6: Retrieval with Scores
#
# Before we generate answers, we should inspect retrieval directly. If retrieval returns poor context, the final answer will usually be poor too.
#
# The value `k` controls how many chunks the retriever returns. A larger `k` gives the model more context, but it can also add noise. We will start with `k = 4` and tune it later.
#
# Qdrant can return both the matching `Document` and a similarity score. This is the same ranking idea we saw with `king`, `queen`, and `cat`, now applied to PDF chunks.

# %%
def display_retrieval_results(query: str, k: int) -> list[tuple]:
    """Retrieve chunks and print a compact view of the results."""
    results = vector_store.similarity_search_with_score(query, k=k)

    for index, (doc, score) in enumerate(results, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        start_index = doc.metadata.get("start_index", "unknown")
        preview = doc.page_content[:350].replace("\n", " ")

        print(f"Source {index} | score={score:.3f} | page={page_display} | start_index={start_index}")
        print(preview)
        print("-" * 80)

    return results

# %%
retrieval_k = 4
retrieval_query = "What signs suggest that a cat should be seen by a veterinarian?"
retrieved_results = display_retrieval_results(retrieval_query, k=retrieval_k)
# Out:
# Source 1 | score=0.584 | page=8 | start_index=0
# Detecting signs of pain or anxiety and evaluation of quality of life are most commonly of concern in the mature adult or senior cat but may be relevant at any life stage. During the physical examination, particular focus is on pain assessment and abdominal and thyroid palpation. A detailed mus- culoskeletal examination to detect signs of osteoarthr
# --------------------------------------------------------------------------------
# Source 2 | score=0.571 | page=7 | start_index=2384
# Asking speci ﬁc questions concerning whether vomiting, vom- iting hairballs, or diarrhea is occurring, and the frequency of each, is recommended as some clients may consider vomiting or vomiting hairballs to be normal for their cat. Additionally, discuss the im- portance of monitoring weight, and ask about any chronic enter- opathy or gastrointesti
# --------------------------------------------------------------------------------
# Source 3 | score=0.565 | page=7 | start_index=3237
# increased nocturnal activity and vocalization as well as changes in the cat ’s normal habits or activity. These may indicate cognitive dysfunction, disease-reduced mobility, pain, or reduced vision. TABLE 3 Diseases and Conditions That Require Particular Focus During Examination, by Life Stage 2021 AAHA/AAFP Feline Life Stage Guidelines JAAHA.ORG 5
# --------------------------------------------------------------------------------
# Source 4 | score=0.554 | page=7 | start_index=820
# 24 Changes in demeanor, activity level, and behavior are additionally key to note and trend over time. Asking speci ﬁc questions as to whether the kitten is displaying any unwanted behaviors, counselling clients on normal kitten be- havior, and giving advice on positive methods to modify unwanted behavior are critical discussion points at this stag
# --------------------------------------------------------------------------------

# %% [markdown]
# #### ❓Question #3
#
# What does a similarity score help you understand, and what does it not prove by itself?
#
# ##### ✅ Answer:
#
# It helps understand relative relevance, aka relative semantic similarity between two texts, enabling ranking of different chunks. It does not prove semantic relevance in absolute quantitative terms.

# %% [markdown]
# ## Task 7: Retrieval Augmented Generation
#
# Now we combine retrieval with generation. We will use a two-step RAG pattern:
#
# 1. Retrieve relevant chunks from Qdrant
# 2. Put those chunks into the prompt and ask the model to answer from the context
#
# This is intentionally simpler than an agent. We always retrieve before answering, which makes the vector retrieval mechanics easy to inspect.
#
# For generation, we will use `gpt-5.4-mini`.

# %%
chat_model = "gpt-5.4-mini"
llm = ChatOpenAI(model=chat_model)

RAG_SYSTEM_PROMPT = """You are a cat health guideline assistant in a vector RAG lesson.

Use only the provided context to answer the user's question.
If the context does not contain enough information, say: "I don't have enough information in the provided cat health guideline PDF to answer that."

Cite the retrieved sources inline using labels like [Source 1] or [Source 2].
Do not diagnose, prescribe medication, or replace a veterinarian.
For diagnosis, treatment decisions, medication questions, or urgent symptoms, recommend contacting a veterinarian.
Keep the answer concise and practical."""

RAG_USER_PROMPT = """Context:
{context}

Question: {question}

Answer from the context above."""

rag_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", RAG_SYSTEM_PROMPT),
        ("human", RAG_USER_PROMPT),
    ]
)

rag_chain = rag_prompt | llm | StrOutputParser()

# %%
def format_context(scored_docs: list[tuple]) -> str:
    """Convert retrieved documents into a source-labeled context string."""
    formatted_chunks = []

    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        page_display = page + 1 if isinstance(page, int) else "unknown"
        source = doc.metadata.get("source", "unknown source")

        formatted_chunks.append(
            f"[Source {index}] {source}, page {page_display}, score {score:.3f}\n"
            f"{doc.page_content}"
        )

    return "\n\n".join(formatted_chunks)


def answer_question(question: str, k: int) -> dict:
    """Run retrieve-then-generate and return the answer plus source metadata."""
    scored_docs = vector_store.similarity_search_with_score(question, k=k)
    context = format_context(scored_docs)
    answer = rag_chain.invoke({"context": context, "question": question})

    sources = []
    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        sources.append(
            {
                "source_label": f"Source {index}",
                "file": doc.metadata.get("source"),
                "page": page + 1 if isinstance(page, int) else None,
                "start_index": doc.metadata.get("start_index"),
                "score": score,
            }
        )

    return {
        "question": question,
        "answer": answer,
        "sources": sources,
        "context": scored_docs,
    }

# %% [markdown]
# Before calling the model, inspect the formatted context. This is the exact text that will be inserted into the RAG prompt.

# %%
example_context = format_context(retrieved_results[:2])
print(example_context[:2000])
# Out:
# [Source 1] cat_health_guidelines.pdf, page 8, score 0.584
# Detecting signs of pain or anxiety and evaluation of quality of life
# are most commonly of concern in the mature adult or senior cat but
# may be relevant at any life stage.
# During the physical examination, particular focus is on pain
# assessment and abdominal and thyroid palpation. A detailed mus-
# culoskeletal examination to detect signs of osteoarthritis is critical as
# this condition is one of the most signi ﬁcant and underdiagnosed
# diseases in cats.
# 23,28 A fundic examination is key to detecting signs of
# ophthalmic disease or hypertension. 29 Practices should employ a
# validated pain assessment scale or tool to diagnose, monitor, and
# assist in the evaluation of patients for subtle signs of pain.
# 30
# Changes in grooming habits, particularly increased grooming,
# may signal a dermatologic issue such as atopy, food allergy, an
# immune-mediated skin condition, infectious or parasitic disease,
# endocrine condition, or paraneoplastic syndrome.
# 31 Reduced grooming
#
# [Source 2] cat_health_guidelines.pdf, page 7, score 0.571
# Asking speci ﬁc questions concerning whether vomiting, vom-
# iting hairballs, or diarrhea is occurring, and the frequency of each, is
# recommended as some clients may consider vomiting or vomiting
# hairballs to be normal for their cat. Additionally, discuss the im-
# portance of monitoring weight, and ask about any chronic enter-
# opathy or gastrointestinal (GI) signs that could indicate early stages of
# disease.
# Mature Adult and Senior Cats
# The medical history and examination of mature adult and senior cats
# will be focused on early detection of disease. Adult and senior cats are
# often diagnosed with comorbidities. Speci ﬁc questions regarding
# changes in appetite, occurrence of polyuria and polydipsia, vomiting,
# vomiting hairballs, or diarrhea are of key importance to guide di-
# agnostic testing. Discussion should also be held with the client about
# increased nocturnal activity and vocalization as well as changes

# %%
answer_k = 4

result = answer_question(
    "What are signs that my cat may need veterinary attention?",
    k=answer_k,
)

print(result["answer"])
print("\nSources:")
for source in result["sources"]:
    print(source)
# Out:
# Signs that may warrant veterinary attention include subtle pain or anxiety signals, especially in adult or senior cats [Source 1]. Examples from the guideline include:
#
# - Changes in grooming, especially **reduced grooming** or **increased grooming** [Source 1][Source 2]
# - Signs of **pain**, **abdominal discomfort**, or **thyroid abnormalities** during an exam [Source 1]
# - **Lameness or stiffness** that could suggest osteoarthritis or other joint pain [Source 1]
# - **Stress/fear behaviors** such as cowering, crouching, hiding, freezing, flinging away, flattened ears, dilated pupils, tense body posture, or hissing/growling/screaming [Source 4]
# - **Behavior changes** like increased nocturnal activity, vocalization, or changes in normal habits/activity [Source 3]
# - **Vomiting, hairballs, diarrhea, appetite changes, increased thirst/urination**, or weight changes, which can indicate disease [Source 3]
#
# If you’re noticing any of these, especially if they’re new, persistent, or worsening, contact a veterinarian for evaluation.
#
# Sources:
# {'source_label': 'Source 1', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 0, 'score': 0.5964846603477094}
# {'source_label': 'Source 2', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 767, 'score': 0.5686142737067996}
# {'source_label': 'Source 3', 'file': 'cat_health_guidelines.pdf', 'page': 7, 'start_index': 2384, 'score': 0.5574493142744373}
# {'source_label': 'Source 4', 'file': 'cat_health_guidelines.pdf', 'page': 8, 'start_index': 3963, 'score': 0.553797854651443}

# %% [markdown]
# ### Vibe Check Queries
#
# Run a few questions that should be answerable from a cat health guideline PDF. Then run one question that may not be answerable and confirm the assistant says it does not have enough information.

# %%
vibe_check_questions = [
    "What preventive care is recommended for cats?",
    "What symptoms should make me call a veterinarian?",
    "What should I know about feeding a healthy adult cat?",
    "Can my cat help me file my taxes?",
]

for question in vibe_check_questions:
    print("Question:", question)
    response = answer_question(question, k=answer_k)
    print(response["answer"])
    print("=" * 100)
    print("\nSources:")
    for cont in response["context"]:
        print(cont)

    print("=" * 100)
    print("=" * 100)
# Out:
# Question: What preventive care is recommended for cats?
# The guidelines recommend **minimum annual veterinary examinations for all cats**, with more frequent visits based on individual needs; **senior cats should be seen at least every 6 months** and more often if they have chronic conditions [Source 4]. They also note that preventive care should include **individualized risk assessment** and preventive healthcare strategies that change over a cat’s lifetime [Source 2].
#
# For parasite prevention, the guidelines say **routine, regular use of broad-spectrum products is likely beneficial for most pet cats**, and cats that go outdoors or spend time away from home may need additional parasite control based on their risk [Source 1].
# ====================================================================================================
#
# Sources:
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 14, 'page_label': '15', 'document_type': 'cat_health_guideline', 'start_index': 1549, '_id': 'f490a7d2989449309e6c06940e580c65', '_collection_name': 'cat_health_guidelines'}, page_content='17,120,121 This approach will\neliminate existing infections, as well as decrease the risk of further\ninfestation and subsequent associated clinical problems. Canine and\nfeline housemates may be at risk of transmission of infectious\nparasites including roundworm and ﬂeas and therefore should be\ntreated in synchronicity with newly acquired kittens or cats. Pre-\nventing cats ’ access to gardens and children ’s play sand areas will,\ncombined with parasite prophylaxis, decrease environmental con-\ntamination with infectious and zoonotic agents such as hookworms\nand Toxoplasma gondii.\n33\nRoutine, regular use of broad-spectrum products is likely to be\nbeneﬁcial for the majority of pet cats, regardless of lifestyle. Certain\noutdoor lifestyles, geographic location, and whether a cat spends time\naway from the home (travel, boarding facilities, groomer, etc.) may\nincrease the existing risk of parasitic infection. Thus, recommen-\ndations for prevention and control should re ﬂect knowledge of the'), 0.657093533460539)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 1, 'page_label': '2', 'document_type': 'cat_health_guideline', 'start_index': 821, '_id': '1e04234d20bd485e87137b3cdf36c499', '_collection_name': 'cat_health_guidelines'}, page_content='alized risk assessment, preventive healthcare strategies, and treat-\nment pathways that evolve as the cat matures.\nAn evidence-guided framework for managing a cat ’s healthcare\nthroughout its lifetime has never been more important in feline\npractice than it is now. Cats are the most popular pet in the United\nStates.\n1 A great anomaly in feline practice is that although most\nowners consider their cats to be family members, cats are sub-\nstantially underserved in the primary care setting compared with\ndogs.\n2 In 2006, owners took their dogs to veterinarians more than\ntwice as often as cats: 2.3 times/year for dogs versus 1.1 times/year\nfor cats.\n3 This healthcare use imbalance persists to the present day.\nCat owners often express a belief that their pets “do not need\nmedical care.” Two reasons for this misconception are that signs of\nillness and pain are often dif ﬁcult to detect in the sometimes re-\nclusive or stoic cat, and that cats are perceived to be self-suf ﬁcient.'), 0.6480369754524983)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 18, 'page_label': '19', 'document_type': 'cat_health_guideline', 'start_index': 1659, '_id': '4097e15e13f44a95b53a1c6abc0d2330', '_collection_name': 'cat_health_guidelines'}, page_content='12. Pittari J, Rodan I, Beekman G, et al. American Association of Feline\nPractitioners. Senior care guidelines. J Feline Med Surg 2009;11:763–78.\n13. AAFP Position Statement. Early spay a nd castration. Available at: catvets.\ncom/public/PDFs/PositionStatements/EarlySpay&Neuter.pdf.\n14. AAFP . Client brochures for cat owners. How do I know if my cat is in\npain? Available at: https://catvets.com/guidelines/client-brochures.\n15. Gough A, Thomas A, O ’Neill D. Part II: cat breeds. In: Gough A,\nThomas A, O ’Neill D, eds. Breed predispositions to disease in dogs and\ncats. 3rd ed. Chichester (UK): John Wiley & Sons; 2018:225 –55.\n16. Hosie MJ, Addie DD, Boucraut-Baralon C, et al. Matrix vaccination\nguidelines: 2015 ABCD recommendations for indoor/outdoor cats, rescue\nshelter cats and breeding catteries. J Feline Med Surg 2015;17:583–7.\n17. Lappin MR, Elston T, Evans L, et al. 2019 AAFP feline zoonoses\nguidelines. J Feline Med Surg 2019;21:1008–21.'), 0.6267747067750677)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 5, 'page_label': '6', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': '238627fee9894bacb2493725098cb41d', '_collection_name': 'cat_health_guidelines'}, page_content='For example, some senior cats aged 10 years and older may remain in\nexcellent physical condition and would be best treated as a mature\nadult at the veterinarian ’s discretion. The guidelines are intended to\nbe a starting point from which individualized care recommenda-\ntions can be developed.\nDiscussion Items for All Life Stages\nThe Task Force recommends a minimum of annual examinations for\nall cats, with increasing frequency as appropriate for their individual\nneeds.\n6 Senior cats should be seen at least every 6 months and more\nfrequently for those with chronic conditions. More information\ncan be found in the AAFP Senior Care Guidelines .\n12 Seeing patients\nand clients at least annually provides an excellent opportunity for\nclient education. Table 2 lists a number of discussion items relevant\nto all life stages. Some topics such as sterilization, claw care, the\nimportance of identi ﬁcation and microchipping, and disaster\npreparedness may be covered once in an initial consultation. The'), 0.6201762647136524)
# ====================================================================================================
# ====================================================================================================
# Question: What symptoms should make me call a veterinarian?
# You should call a veterinarian if your cat has vomiting, vomiting hairballs, diarrhea, changes in appetite, increased urination or thirst, increased nocturnal activity or vocalization, or changes in normal habits or activity [Source 1]. In senior cats, changes in jumping or climbing can also be important, and signs like cognitive dysfunction, pain, hyperthyroidism, or hypertension may be involved [Source 2][Source 3].
#
# I don’t have enough information in the provided cat health guideline PDF to answer that more specifically.
# ====================================================================================================
#
# Sources:
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 2384, '_id': '7a0a84d2ccd44698af2a866736641886', '_collection_name': 'cat_health_guidelines'}, page_content='Asking speci ﬁc questions concerning whether vomiting, vom-\niting hairballs, or diarrhea is occurring, and the frequency of each, is\nrecommended as some clients may consider vomiting or vomiting\nhairballs to be normal for their cat. Additionally, discuss the im-\nportance of monitoring weight, and ask about any chronic enter-\nopathy or gastrointestinal (GI) signs that could indicate early stages of\ndisease.\nMature Adult and Senior Cats\nThe medical history and examination of mature adult and senior cats\nwill be focused on early detection of disease. Adult and senior cats are\noften diagnosed with comorbidities. Speci ﬁc questions regarding\nchanges in appetite, occurrence of polyuria and polydipsia, vomiting,\nvomiting hairballs, or diarrhea are of key importance to guide di-\nagnostic testing. Discussion should also be held with the client about\nincreased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive'), 0.43486961529718127)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 4793, '_id': 'e43fdc3e8a354dfd839273f612540a79', '_collection_name': 'cat_health_guidelines'}, page_content='dysfunction syndrome, pain, hyper thyroidism, or hypertension. V et-\nerinary visits may be more challenging for the senior cat, in part be-\ncause many cat owners do not seek wellness visits, but present their\ncats only for acute care.\n3 The use of pheromones or pre–veterinary visit\npharmaceuticals such as gabapentin or trazodone may reduce stress\nwhile allowing thorough evaluations.\n68–71 As many senior patients may\nbe experiencing some level of pain related to their disease or second-\narily to DJD, analgesics may also be indicated for veterinary visits.\nDJD and/or muscle weakness may initially manifest as a change\nor reduction in jumping or climbing in senior cats. Because of the\nPunishment\nCats should not be punished. Yelling at or startling the cat, spraying the\ncat with water, or other physical forms of punishment only serve to scare\nthe cat and may lead to cats running a way or responding aggressively.\nCats should never be subjected to shock collars. Withholding resources,'), 0.4041295740705103)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 3237, '_id': '171f27f3283d4d669fca16ad625d3931', '_collection_name': 'cat_health_guidelines'}, page_content='increased nocturnal activity and vocalization as well as changes in\nthe cat ’s normal habits or activity. These may indicate cognitive\ndysfunction, disease-reduced mobility, pain, or reduced vision.\nTABLE 3\nDiseases and Conditions That Require Particular Focus During Examination, by Life Stage\n2021 AAHA/AAFP Feline Life Stage Guidelines\nJAAHA.ORG 57'), 0.4004609673374146)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 6, 'page_label': '7', 'document_type': 'cat_health_guideline', 'start_index': 820, '_id': '8a4617dbaa4243df9e9114fd7a049f16', '_collection_name': 'cat_health_guidelines'}, page_content='24 Changes in\ndemeanor, activity level, and behavior are additionally key to note\nand trend over time.\nAsking speci ﬁc questions as to whether the kitten is displaying\nany unwanted behaviors, counselling clients on normal kitten be-\nhavior, and giving advice on positive methods to modify unwanted\nbehavior are critical discussion points at this stage. Breed-related\npredispositions, signs of genetic disease, and the availability and\naccuracy of genetic testing to detect disease should be discussed when\nrelevant.\nThe physical examination for k ittens typically focuses on\ndetection of congenital issues such as a heart murmur, hernia, or\ncleft palate. A detailed oral examination is performed to detect\nabnormalities of dentition. The use of fecal scoring charts is very\nhelpful to ensure that the client can accurately identify stool\nconsistency.\n25,26\nYoung Adult Cats\nLower airway disease is common in young adult cats.\n27 Coughing is a'), 0.3901654764523437)
# ====================================================================================================
# ====================================================================================================
# Question: What should I know about feeding a healthy adult cat?
# For a healthy adult cat, feeding should be based on the cat’s individual needs, including age, reproductive status, body condition score (BCS), muscle condition score (MCS), activity level, health status, and future health concerns [Source 2].
#
# A practical starting point for daily calories is to calculate resting energy requirements (RER) using **RER = 30 × body weight in kg + 70**, then adjust to daily energy requirements (DER) using a needs factor; for **young, healthy adults, the factor is 1** [Source 1]. Food intake can then be estimated by comparing DER with the food’s caloric density [Source 1].
#
# Cats should be fed diets labeled with an **AAFCO statement of nutritional adequacy** to help avoid nutrient deficiencies [Source 2]. The guidelines also note that cats should not be fed raw or dehydrated non-sterilized foods, including animal-origin treats [Source 2].
#
# To maintain healthy weight, the amount fed should be adjusted to keep the cat in ideal body condition, and overweight cats should not simply be fed less of a maintenance diet because that can cause vitamin and mineral deficiencies [Source 3][Source 1]. If you’re trying to decide the best feeding plan for an individual cat, a veterinarian can help tailor it.
# ====================================================================================================
#
# Sources:
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 13, 'page_label': '14', 'document_type': 'cat_health_guideline', 'start_index': 0, '_id': 'c306de4bb6a94b2980a107c766720444', '_collection_name': 'cat_health_guidelines'}, page_content='good starting point is to calculate the adult feline patient ’s resting\nenergy requirements (RER) according to the following calculation:\nRER (kcal per day) ¼ 30 × (body weight in kg) 1 70. Daily energy\nrequirements (DER) are determined based on multiplying by a\nneeds factor, which in the case of young, healthy adults is 1. Food\nintake can be determined by comparing DER with the caloric\ndensity of the patient ’s foods.\n85,98–100\nPrescription diets are indicated for obesity treatment. These\nweight loss diets are formulated to provide adequate vitamins and\nminerals with reduced caloric content. It is important to inform\nowners of overweight cats that simply feeding less of a maintenance\ndiet in order to reduce caloric intake may result in vitamin and\nmineral de ﬁciencies.\nMature Adult and Senior Cats\nMature adult and senior cats have changing dietary needs, and it is\nextremely important to provide guidance on daily feeding amounts.'), 0.6631850129475978)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 12, 'page_label': '13', 'document_type': 'cat_health_guideline', 'start_index': 1658, '_id': '9eeabde7402d443bb1f4b67a652866bd', '_collection_name': 'cat_health_guidelines'}, page_content='to hunt and feed several times during the day.\n82 Because of evolutionary\nchanges, the domestic cat has lost key metabolic enzymes, and this has\nresulted in very narrowly de ﬁned nutritional requirements.\n83 All cats\nrequire protein, which is composed of 23 different amino acids; 11 are\nconsidered essential for the cat. Deﬁciencies in any essential nutrients\ncould result in health problems.\n83 No matter the life stage, to help\navoid potential nutrient insufﬁciencies, cats should be fed diets labeled\nwith an Association of American Feed Control Of ﬁcials statement of\nnutritional adequacy. AAHA and the AAFP do not advocate or en-\ndorse feeding cats any raw or dehydrated non-sterilized foods, in-\ncluding treats that are of animal origin.\n84\nIn order to make a nutritional recommendation, the practice\nteam can assess nutritional status based on age, reproductive status,\nBCS, MCS, activity level, presence of disease, and future health\nconcerns for the individual cat.'), 0.6457804781621036)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 12, 'page_label': '13', 'document_type': 'cat_health_guideline', 'start_index': 4062, '_id': 'a898fbc9b5514909990c87c6d4a0c73f', '_collection_name': 'cat_health_guidelines'}, page_content='tional needs, obesity risks, and prevention strategies for the indi-\nvidual patient. Recommendations can be found in the AAFP ’s Feline\nFeeding Programs Consensus Statement.\n19\nYoung Adult Cats\nEnergy requirements of cats are in ﬂuenced by a variety of factors\nincluding age (i.e., life stage), BCS, MCS, neuter status, health status,\nand activity level. Using indirect calorimetry, young adult active cats\nhave been shown to have higher energy requirements compared with\nsenior cats.\n90\nThe amount fed should be adjusted to maintain or encourage\nideal body condition, and a BCS should be documented by the\nveterinarian at each visit.\n91 Photographs (dorsal and lateral) of the\ncat can be obtained and recorded. A BCS of 6/9 or 7/9 is con-\nsidered overweight, and a score of greater than or equal to 8/9 is\nconsidered obese.\n92 The prevalence of obesity in cats ranges from\n1.8 to 40% in published studies. 60 Being overweight or obese can'), 0.6457181717818306)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 12, 'page_label': '13', 'document_type': 'cat_health_guideline', 'start_index': 2466, '_id': 'd8aa8404f4464543a4e11de43f9bba21', '_collection_name': 'cat_health_guidelines'}, page_content='team can assess nutritional status based on age, reproductive status,\nBCS, MCS, activity level, presence of disease, and future health\nconcerns for the individual cat.\n85 A diet is selected to best meet the\nnutritional needs of the patient, and a speci ﬁc feeding plan is then\ndeveloped. Clinical discretion is applied to allow gradual tran-\nsitioning to the new diet over 7 –10 days.\n85\nKittens\nKittens can be weaned onto commercially balanced kitten foods\nstarting at 3 –5 weeks of age. Growing kittens at 10 weeks of age\nhave a very high energy requirement of 200 kcal/kg body weight/\nday compared with 80 kcal/kg/day at 10 months of age. Generally,\nkitten food preferences have been reported to be highly in ﬂuenced\nby the queen (i.e., the primary effect),\n86 although these prefer-\nences can be modi ﬁed in the adult cat based on experiences. 83\nBehavioral and ethological research both suggest that cats prefer to\neat individually in a quiet location where they will not be startled'), 0.6372435730062724)
# ====================================================================================================
# ====================================================================================================
# Question: Can my cat help me file my taxes?
# I don’t have enough information in the provided cat health guideline PDF to answer that. If you have a cat behavior or health concern, it’s best to contact a veterinarian.
# ====================================================================================================
#
# Sources:
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 9, 'page_label': '10', 'document_type': 'cat_health_guideline', 'start_index': 1637, '_id': '8eacde842dd84195a1b0a8f7123079e1', '_collection_name': 'cat_health_guidelines'}, page_content='Young Adult Cats\nY oung adult cats do not require as frequent routine medical care as\nkittens, so it is integral to educate the client about why regular\nhealthcare examinations remain so important. Routine examinations\ncan help identify behavioral changes or medical concerns that may\naffect a cat ’s health long before they become signi ﬁcant, painful, or\nmore costly to treat. Clients should be educated about the subtle\nchanges in behavior and day-to-day life of the cat that may possibly\nbe signi ﬁcant. Encouraging owners to routinely record behaviors in\na journal and/or with photos and video will provide a basis for\ndocumenting any such changes. Simply asking the client, “Is your\ncat happy? ” may help them think about their cat ’s welfare.\nUrine marking is most often displayed by intact male cats,\nalthough one study reported that about 10% of sterilized cats marked\ntheir territory with urine.\n54 The onset of this behavior can coincide'), 0.37977627011578563)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 19, 'page_label': '20', 'document_type': 'cat_health_guideline', 'start_index': 2443, '_id': 'ab1cd591f4ed4aa8ab6971081bd67532', '_collection_name': 'cat_health_guidelines'}, page_content='silvestris catus) kept in the home. Appl Anim Behav Sci 2005;93:97–109.\n62. Clancy EA, Moore AS, Bertone ER. Evaluation of cat and owner\ncharacteristics and their relationships to outdoor access of owned cats. J\nAm V et Med Assoc 2003;222:1541–5.\n63. Neville PF. An ethical viewpoint: the role of veterinarians and behaviourists\nin ensuring good husbandry for cats. J Feline Med Surg 2004;6:43–8.\n64. T oribio JLM, Norris JM, White JD, et al. Demographics and husbandry\nof pet cats living in Sydney, Australia: results of cross-sectional survey of\npet ownership. J Feline Med Surg 2009;11:449–61.\n65. Rochlitz I. The welfare of cats . Dordrecht (Netherlands): Springer; 2005.\n66. Clarke DL, Wrigglesworth D, Holmes K, et al. Using environmental\nenrichment and feeding enrichment to facilitate feline weight loss. J\nAnim Physiol Anim Nutr (Berl) 2005;89:427. DOI: 10.1111/j.1439-\n0396.2005.00611_1.x.\n67. AAFP Position Statement: Positive reinforcement for cats. 2012. Available at:'), 0.37925070015033074)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 18, 'page_label': '19', 'document_type': 'cat_health_guideline', 'start_index': 3249, '_id': '63d4edaadced474c9e2b7bc464dbcefe', '_collection_name': 'cat_health_guidelines'}, page_content='free-roaming cats. Top Companion Anim Med 2017;32:91–5.\n22. Whyte A, Lacasta S, Whyte J, et al. T ooth resorption in Spanish do-\nmestic cats: preliminary data. Top Companion Anim Med 2020;38:\n100369. DOI: 10.1016/j.tcam.2019.100369.\n23. Bennett D, Arifﬁn SMZ, Johnston P . Osteoarthritis in the cat: how common\nis it and how easy to recognise? J Feline Med Surg 2012;14:65–75.\n24. AAHA. 2010 AAHA nutritional assessment guidelines for dogs and cats.\nAvailable at: aaha.org/aaha-guidelines/nutritional-assessment-conﬁguration/\nnutritional-assessment-introduction/.\n25. Purina. Fecal Scoring Chart. Available at: https://www.proplanveterinarydiets.ca/\nwp-content/uploads/2018/05/180107_PPPVD-Fecal-Scoring-Chart-UP-\nDATE-EN-FINAL.pdf.\n26. Royal Canin. Fecal Scoring System for Cats. 2020. Available at: https://\nroyalcanin-us.my.salesforce.com/sfc/p/j0000001rD9A/a/5b000000QMW8/\n8FRFiG8lTxRVN0rrLvXHrb9shSxH3cqoC.XA.ltJj2s.\n27. Rozanski E. Feline lower airway disease. In: Little S, ed. August’s con-'), 0.36667451707688603)
# (Document(metadata={'producer': 'Acrobat Distiller 10.0.0 (Windows)', 'creator': 'Adobe InDesign CS6 (Windows)', 'creationdate': '2021-02-02T08:52:15-05:00', 'author': '7123', 'moddate': '2021-02-02T07:53:51-07:00', 'title': 'djs_jaaha_56_5_COVER.indd', 'source': 'cat_health_guidelines.pdf', 'total_pages': 22, 'page': 7, 'page_label': '8', 'document_type': 'cat_health_guideline', 'start_index': 3153, '_id': 'a017d96683da41fc93f95581588f3c8c', '_collection_name': 'cat_health_guidelines'}, page_content='36\nCats are popular pets that reside in 25% of U.S. households with\na mean of 1.8 cats per household, 39 a demographic statistic that\nhighlights the importance of understanding often complex feline\ninterrelationships. Many people believe their cats get along, whereas\nin reality, they may display overt aggression (hissing or swatting) or\nbecome passively avoidant. In contrast, af ﬁliative relationships are\ncharacterized by behaviors such as allogrooming, nose touching, or\nsleeping in close contact.\n40,41\nFeline Communication Signs\nAlthough cats may be distressed, they are stealthy in their ability to\nhide anxiety. A content cat will hold its ears forward, whiskers loose\nor relaxed, muscles soft, and tail loosely wrapped. Practitioners\nshould closely observe feline body language postures for even the\nmost subtle signs of anxiety and tension. Clinical signs of fear or\nstress in cats are displayed through characteristic body postures,'), 0.36480933567025353)
# ====================================================================================================
# ====================================================================================================

# %% [markdown]
# #### ❓Question #4
#
# For the vibe check queries above, did the retrieved context seem relevant before generation? Why or why not?
#
# ##### ✅ Answer:
#
# The context seems relevant for all queries except the last one. While for the 3 queries related to the document corpus the retrieved chunks were actually helpful in answering in the last case they were not and the llm correctly recognizes that.
# Interestingly the retrieval step as implemented always retrieves some chunks, consistently with the fact that semantic similarity can be used for relative ranking of chunks. If no chunk is relevant we still get some results. Also having an absolute cutoff on the relevance score would be hard to tune given that we have no reason to believe there to be a unique threshold that is applicable across different queries.
#
# Fun Fact: some chunks retrieved on the query about taxes are related to stress and anxiety in cats :-) . Which is not far-fetched imo...

# %% [markdown]
# Fun## 🏗️ Activity: Tune Retrieval Quality
#
# Improve retrieval quality by changing one or more of these values:
#
# - The chunk size
# - The chunk overlap
# - The retrieval `k`
# - The wording of the retrieval query
#
# Suggested workflow:
#
# 1. Pick one test question.
# 2. Inspect the retrieved chunks and scores.
# 3. Change one retrieval setting.
# 4. Rebuild the splitter and vector store.
# 5. Compare whether the retrieved chunks became more relevant.
#
# When you are done, write down what changed and whether the final answer improved.

# %%
# Activity workspace
# Try retrieval tuning here.

### YOUR CODE HERE
from html import escape
from IPython.display import display, HTML
from markdown import markdown

def e_2_e_rag_setup_query(
    question: str,
    chunk_size: int,
    chunk_overlap: int,
    k: int = 4,
) -> dict:
    """Rebuild chunking + Qdrant and answer a question for one tuning setup."""

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        add_start_index=True,
    )

    splits = text_splitter.split_documents(pages)

    tuned_vector_store = QdrantVectorStore.from_documents(
        documents=splits,
        embedding=embeddings,
        location=":memory:",
        collection_name=f"cat_health_guidelines_{chunk_size}_{chunk_overlap}",
        force_recreate=True,
    )

    scored_docs = tuned_vector_store.similarity_search_with_score(question, k=k)
    context = format_context(scored_docs)
    answer = rag_chain.invoke({"context": context, "question": question})

    sources = []
    for index, (doc, score) in enumerate(scored_docs, start=1):
        page = doc.metadata.get("page")
        sources.append(
            {
                "source_label": f"Source {index}",
                "file": doc.metadata.get("source"),
                "page": page + 1 if isinstance(page, int) else None,
                "start_index": doc.metadata.get("start_index"),
                "score": score,
                "preview": doc.page_content[:250].replace("\n", " "),
            }
        )

    return {
        "question": question,
        "answer": answer,
        "sources": sources,
        "retrieved_chunks": scored_docs,
        "chunk_count": len(splits),
        "chunk_size": chunk_size,
        "chunk_overlap": chunk_overlap,
        "retrieval_k": k,
    }


question = "What preventive care is recommended for cats?"


def visualize_results(response):

    print("Question:", response["question"])
    print(
        f"Built {response['chunk_count']} chunks "
        f"with chunk_size={response['chunk_size']} and chunk_overlap={response['chunk_overlap']}."
    )
    display(
        HTML(
            f"""
            <div style="white-space: normal; overflow-wrap: anywhere; margin: 0.5rem 0 1rem 0;">
                {markdown(response["answer"])}
            </div>
            """
        )
    )
    print("=" * 100)
    print("\nSources:")

    source_sections = []
    for source in response["sources"]:
        summary = (
            f"{source['source_label']} | page={source['page']} | "
            f"start_index={source['start_index']} | score={source['score']:.3f}"
        )

        source_sections.append(
            f"""
            <details open style="margin-bottom: 0.75rem;">
            <summary style="cursor: pointer; font-weight: 600;">{escape(summary)}</summary>
            <pre style="white-space: pre-wrap; margin-top: 0.5rem;">{escape(source['preview'])}</pre>
            </details>
            """
        )

    display(HTML("".join(source_sections)))

# %%
response = e_2_e_rag_setup_query(
    question=question,
    chunk_size=1000,
    chunk_overlap=200,
    k=4,
)

visualize_results(response)
# Out:
# Question: What preventive care is recommended for cats?
# Built 135 chunks with chunk_size=1000 and chunk_overlap=200.
#             <div style="white-space: normal; overflow-wrap: anywhere; margin: 0.5rem 0 1rem 0;">
#                 <p>The guidelines recommend <strong>individualized preventive care</strong> based on a cat’s life stage and risk factors, with <strong>at least annual veterinary examinations for all cats</strong> and more frequent visits as needed [Source 4]. Preventive strategies may include <strong>routine broad-spectrum parasite prevention</strong>, especially because many cats benefit from it regardless of lifestyle [Source 1]. The guidelines also note that <strong>housemates may need treatment in synchronicity</strong> for parasites, and limiting access to gardens and children’s sand areas can help reduce environmental contamination [Source 1].</p>
#             </div>
# ====================================================================================================
#
# Sources:
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 1 | page=15 | start_index=1549 | score=0.657</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">17,120,121 This approach will eliminate existing infections, as well as decrease the risk of further infestation and subsequent associated clinical problems. Canine and feline housemates may be at risk of transmission of infectious parasites includin</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 2 | page=2 | start_index=821 | score=0.648</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">alized risk assessment, preventive healthcare strategies, and treat- ment pathways that evolve as the cat matures. An evidence-guided framework for managing a cat ’s healthcare throughout its lifetime has never been more important in feline practice </pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 3 | page=19 | start_index=1659 | score=0.627</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">12. Pittari J, Rodan I, Beekman G, et al. American Association of Feline Practitioners. Senior care guidelines. J Feline Med Surg 2009;11:763–78. 13. AAFP Position Statement. Early spay a nd castration. Available at: catvets. com/public/PDFs/Position</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 4 | page=6 | start_index=0 | score=0.620</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are intended to be a starting point from which individualiz</pre>
#             </details>

# %%
response = e_2_e_rag_setup_query(
    question=question,
    chunk_size=300,
    chunk_overlap=200,
    k=4,
)

visualize_results(response)
# Out:
# Question: What preventive care is recommended for cats?
# Built 973 chunks with chunk_size=300 and chunk_overlap=200.
#             <div style="white-space: normal; overflow-wrap: anywhere; margin: 0.5rem 0 1rem 0;">
#                 <p>Recommended preventive care for cats includes internal and external parasite control, vaccination, and management to prevent roaming [Source 1]. The guidelines also note that regular preventive healthcare examinations are recommended for apparently healthy cats [Source 2].</p>
#             </div>
# ====================================================================================================
#
# Sources:
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 1 | page=16 | start_index=1021 | score=0.678</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">Basic preventive healthcare (e.g., internal and external parasite control, vaccination) protects both feline and human health and is further enhanced by management to prevent pet roaming. Under- standing and instituting proper biosecurity measures is</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 2 | page=16 | start_index=2685 | score=0.666</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">4. These recommendations are intended for apparently healthy cats and do not extend to preanesthetic laboratory work. Although speciﬁc data documenting beneﬁts are not available, the T ask Force concluded that regular preventive healthcare examinatio</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 3 | page=16 | start_index=963 | score=0.654</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">practice team and help guide discussions with pet owners. Basic preventive healthcare (e.g., internal and external parasite control, vaccination) protects both feline and human health and is further enhanced by management to prevent pet roaming. Unde</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 4 | page=16 | start_index=2498 | score=0.651</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">can also be reduced by the use of regular, effective ﬂea prevention. 17 Recommended Diagnostics Based on Life Stage Recommended diagnostics according to life stage are outlined in T able 4. These recommendations are intended for apparently healthy ca</pre>
#             </details>

# %%
response = e_2_e_rag_setup_query(
    question=question,
    chunk_size=3000,
    chunk_overlap=200,
    k=4,
)

visualize_results(response)
# Out:
# Question: What preventive care is recommended for cats?
# Built 46 chunks with chunk_size=3000 and chunk_overlap=200.
#             <div style="white-space: normal; overflow-wrap: anywhere; margin: 0.5rem 0 1rem 0;">
#                 <p>Preventive care for cats in the guideline includes:</p>
# <ul>
# <li><strong>At least annual veterinary examinations</strong> for all cats; <strong>senior cats should be seen at least every 6 months</strong> and more often if they have chronic conditions [Source 4].</li>
# <li><strong>Basic preventive healthcare</strong>, including <strong>internal and external parasite control</strong> and <strong>vaccination</strong> [Source 2].</li>
# <li><strong>Regular broad-spectrum parasite prevention</strong> is likely beneficial for most pet cats, with recommendations adjusted for the cat’s lifestyle, exposure risks, and geography [Source 1].</li>
# <li><strong>Regular fecal examinations</strong> when appropriate, based on health and lifestyle factors [Source 3].</li>
# <li><strong>Dental preventive care</strong>, including periodic complete dental prophylaxis with <strong>full oral dental radiography</strong>, even if no obvious problems are seen [Source 1].</li>
# <li><strong>Client education</strong> about normal behavior, subtle signs of illness or pain, and breed predispositions to help owners seek care early [Source 4].</li>
# </ul>
# <p>If you want, I can also summarize this as a short checklist for a cat wellness visit.</p>
#             </div>
# ====================================================================================================
#
# Sources:
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 1 | page=15 | start_index=0 | score=0.673</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">disease, masses, or orofacial pain can be made before problems es- calate and cause pain and hyporexia. 107,113,114 The use of photographic or radiographic images of sequential oral examinations, as well as scoring sheets for dental pathology, genera</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 2 | page=16 | start_index=0 | score=0.640</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">space, administration at this location is not recommended. Educa- tion of owners regarding injection-site reactions is prudent. Prac- titioners are strongly advised to keep complete, accurate records of antigen administration site and route of vaccin</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 3 | page=17 | start_index=0 | score=0.621</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">For cats of all ages, timing and frequency of diagnostics may depend on lifestyle, exposure risks, and geographic location. Retroviral testing recommendations are discussed in detail in the 2020 AAFP Feline Retrovirus Testing and Management Guideline</pre>
#             </details>
#
#             <details open style="margin-bottom: 0.75rem;">
#             <summary style="cursor: pointer; font-weight: 600;">Source 4 | page=6 | start_index=0 | score=0.608</summary>
#             <pre style="white-space: pre-wrap; margin-top: 0.5rem;">For example, some senior cats aged 10 years and older may remain in excellent physical condition and would be best treated as a mature adult at the veterinarian ’s discretion. The guidelines are intended to be a starting point from which individualiz</pre>
#             </details>

# %% [markdown]
# ### 🏗️ Activity Notes
#
# - Setting changed: chunk size
# - Before: 1000
# - After: 3000
# - Did retrieval improve? Why or why not?
#   - As expected a much larger chunk size resulted in retrieve sources that were less focused on the actual question but also provided more details to the llm for the generation (I kept k fixed). I am not sure if the end results actually improved as that would depend very much on target users and their preferences. Larger chunk size resulted  in the llm providing a more detailed response in this case. Not sure if this is actually good for the use case at hand.
